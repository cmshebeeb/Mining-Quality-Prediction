# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/MiningProcess_Flotation_Plant_Database.csv', decimal=',', on_bad_lines='skip')
#print(df.head())
#print(df.info())
#print(df.shape)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from google.colab import drive
# !git config --global user.email "mshebeebc@gmail.com"
# !git config --global user.name "Muhammed Shebeeb C"
# !git clone https://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@github.com/cmshebeeb/Mining-Quality-Prediction.git
# %cd Mining-Quality-Prediction
# !mkdir -p notebooks
# !cp /content/Mining_Data_Exploration.ipynb ./notebooks/
# !git add notebooks/Mining_Data_Exploration.ipynb
# !git commit -m "Upload initial dataset exploration notebook"
# !git push origin main
# Out:
# Cloning into 'Mining-Quality-Prediction'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 8 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (8/8), 5.27 KiB | 5.27 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# /content/Mining-Quality-Prediction/Mining-Quality-Prediction/Mining-Quality-Prediction
# cp: cannot stat '/content/Mining_Data_Exploration.ipynb': No such file or directory
# fatal: pathspec 'notebooks/Mining_Data_Exploration.ipynb' did not match any files
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
